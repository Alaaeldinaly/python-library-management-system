# %% [markdown]
# <a href="https://colab.research.google.com/github/Alaaeldinaly/python-library-management-system/blob/main/library_management_assignment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)

# %%
# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# Add two more books to the list
books.append("Machine Learning with Python")
books.insert(1, "Python for Beginners")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python']

# %%
# 3. Loops and range()
print("\nAvailable books:")
for i in range(len(books)):
    print(f"{i}: {books[i]}")
# Out:
# Available books:
# 0: Python Basics
# 1: Python for Beginners
# 2: Advanced Python
# 3: Data Science with Python
# 4: Machine Learning with Python

# %%
# 4. User Input
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Enter a new book title: Dream
# Updated book list: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Dream']

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    if book_name in books:
        return True
    else:
        return False

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %%
# 6. File I/O
def save_books_to_file(filename):
    try:
        with open(filename, 'w') as f:
            for book in books:
                f.write(f"{book}\n")
    except Exception as e:
        print("Error saving books to file:", e)

def read_books_from_file(filename):
    try:
        with open(filename, 'r') as f:
            return [line.strip() for line in f.readlines()]
    except FileNotFoundError:
        print("File not found.")
        return []
    except Exception as e:
        print("Error reading file:", e)
        return []

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt

print("Books read from file:", read_books_from_file("books.txt"))
# Out:
# Python Basics
# Python for Beginners
# Advanced Python
# Data Science with Python
# Machine Learning with Python
# Dream
# Books read from file: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Dream']

# %%
# 7. Pickle for serialization
def save_books_pickle(filename):
    try:
        with open(filename, 'wb') as f:
            pickle.dump(books, f)
    except Exception as e:
        print("Error saving pickle file:", e)

def load_books_pickle(filename):
    try:
        with open(filename, 'rb') as f:
            return pickle.load(f)
    except FileNotFoundError:
        print("Pickle file not found.")
        return []
    except Exception as e:
        print("Error loading pickle file:", e)
        return []

# Test pickle functions
save_books_pickle("books.pkl")
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Dream']

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

def add_book_to_db(title, quantity):
    try:
        conn = sqlite3.connect('library.db')
        cursor = conn.cursor()
        cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)", (title, quantity))
        conn.commit()
        conn.close()
        print(f"Book '{title}' added to database with quantity {quantity}.")
    except Exception as e:
        print("Database error:", e)

# Test database functions
create_books_table()
add_book_to_db("Python for Beginners", 10)

# Optional: display database contents
conn = sqlite3.connect('library.db')
cursor = conn.cursor()
cursor.execute("SELECT * FROM books")
rows = cursor.fetchall()
print("Database contents:", rows)
conn.close()
# Out:
# Book 'Python for Beginners' added to database with quantity 10.
# Database contents: [(1, 'Python for Beginners', 10)]

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'Python']
#
# Library Management System operations completed.

# %%
def remove_book(book_name):
    if book_name in books:
        books.remove(book_name)
        print(f"{book_name} removed successfully.")
    else:
        print(f"{book_name} not found.")

remove_book("Advanced Python")
print("Books after removal:", books)
# Out:
# Advanced Python removed successfully.
# Books after removal: ['Python Basics', 'Python for Beginners', 'Data Science with Python', 'Machine Learning with Python', 'Dream']
